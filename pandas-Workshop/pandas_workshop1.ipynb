# %% [markdown]
# # Import library and check version

# %%
import sys

print(sys.executable)
print(sys.version)
# Out:
# /usr/local/bin/python
# 3.13.14 (main, Jul 14 2026, 04:45:36) [GCC 14.2.0]

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt


print(f"Pandas version: {pd.__version__}")
print(f"Numpy version: {np.__version__}")
print(f"Matplotlib version: {plt.matplotlib.__version__}")
# Out:
# Pandas version: 3.0.5
# Numpy version: 2.5.1
# Matplotlib version: 3.11.1

# %%
import IPython
from IPython.display import display, Markdown, Latex, HTML, IFrame, JSON, Code, Image, YouTubeVideo, clear_output
print( f"IPython {IPython.__version__}" )
# Out:
# IPython 9.16.1

# %%
import pyarrow as pa

print(pa.__version__)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 import pyarrow as pa
#       2
#       3 print(pa.__version__)
#
# ModuleNotFoundError: No module named 'pyarrow'

# %%
print(sys.executable)
# Out:
# /usr/local/bin/python

# %% [markdown]
# # 2. Pandas: Create data

# %%
# Let pandas figure out a suitable data type for the created Series
sr = pd.Series( [10,20.5,30.6,100,1000] )

# Inspect the data
print( f"type = {type(sr)}" )
print( f"shape = {sr.shape}" )
print( f"dtype = {sr.dtype}\n" )
display( sr )
# Out:
# type = <class 'pandas.Series'>
# shape = (5,)
# dtype = float64
# 0      10.0
# 1      20.5
# 2      30.6
# 3     100.0
# 4    1000.0
# dtype: float64

# %%
# Create a series with a proper data type to avoid an error
sr1 = pd.Series( [10,20.5,30.6,100,1000], dtype='float64' )   # The default numpy backend
sr2 = pd.Series( [10,20.5,30.6,100,1000], dtype='float64[pyarrow]' )  # The pyarrow backend

# Inspect
display(sr1)
display(sr2)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[8], line 3
#       1 # Create a series with a proper data type to avoid an error
#       2 sr1 = pd.Series( [10,20.5,30.6,100,1000], dtype='float64' )   # The default numpy backend
# ----> 3 sr2 = pd.Series( [10,20.5,30.6,100,1000], dtype='float64[pyarrow]' )  # The pyarrow backend
#       4
#       5 # Inspect
#       6 display(sr1)
#
# File /usr/local/lib/python3.13/site-packages/pandas/core/series.py:426, in Series.__init__(self, data, index, dtype, name, copy)
#     423     index = ensure_index(index)
#     425 if dtype is not None:
# --> 426     dtype = self._validate_dtype(dtype)
#     428 if data is None:
#     429     index = index if index is not None else default_index(0)
#
# File /usr/local/lib/python3.13/site-packages/pandas/core/generic.py:477, in NDFrame._validate_dtype(cls, dtype)
#     473     @classmethod
#     474     def _validate_dtype(cls, dtype) -> DtypeObj | None:
#     475         """validate the passed dtype"""
#     476         if dtype is not None:
# --> 477             dtype = pandas_dtype(dtype)
#     478
#     479             # a compound dtype
#     480             if dtype.kind == "V" and not isinstance(dtype, ExtensionDtype):
#
# File /usr/local/lib/python3.13/site-packages/pandas/core/dtypes/common.py:1862, in pandas_dtype(dtype)
#    1859     return StringDtype(na_value=np.nan)
#    1861 # registered extension types
# -> 1862 result = registry.find(dtype)
#    1863 if result is not None:
#    1864     if isinstance(result, type):
#    1865         # GH 31356, GH 54592
#
# File /usr/local/lib/python3.13/site-packages/pandas/core/dtypes/base.py:590, in Registry.find(self, dtype)
#     588 for dtype_type in self.dtypes:
#     589     try:
# --> 590         return dtype_type.construct_from_string(dtype)
#     591     except TypeError:
#     592         pass
#
# File /usr/local/lib/python3.13/site-packages/pandas/core/dtypes/dtypes.py:2377, in ArrowDtype.construct_from_string(cls, string)
#    2375     raise TypeError("string[pyarrow] should be constructed by StringDtype")
#    2376 if not HAS_PYARROW:
# -> 2377     raise ImportError(
#    2378         f"pyarrow>={PYARROW_MIN_VERSION} is required for ArrowDtype"
#    2379     )
#    2381 base_type = string[:-9]  # get rid of "[pyarrow]"
#    2382 try:
#
# ImportError: pyarrow>=13.0.0 is required for ArrowDtype
